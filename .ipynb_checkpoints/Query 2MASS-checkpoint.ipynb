# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Initiate-Database-Connection" data-toc-modified-id="Initiate-Database-Connection-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Initiate Database Connection</a></span></li><li><span><a href="#Query-fp_psc-:-2MASS-All-Sky-Point-Source-Catalog-(PSC)" data-toc-modified-id="Query-fp_psc-:-2MASS-All-Sky-Point-Source-Catalog-(PSC)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Query fp_psc : 2MASS All-Sky Point Source Catalog (PSC)</a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd
from astropy import units as u
from astropy.coordinates import SkyCoord

# %%
main_dir = "/Volumes/LaCie/Research/NAC/"
data_dir = main_dir+"data/"
out_dir = main_dir+"output/"

# %%
df = pd.read_csv(data_dir+"MN_17_3616_point.csv",
                index_col = 0)

# %%
df.head(4)
# Out:
#                 Name         RA        Dec  K2MASS  (V-K)o  Period  Ref   BCK  \
# 0  J03394633+2358531  54.943067  23.981442   11.83    4.89   1.138    1  2.73
# 1  J03414664+2301198  55.444367  23.022186   13.16    5.63   0.294    1  2.81
# 2  J03414895+2303235  55.453963  23.056539   13.19    6.09   0.239    1  2.86
# 3  J03415671+2358434  55.486317  23.978728   13.25    5.76   0.401    1  2.82
#
#    logL/Lo  M/Mo   ...     teff_val  teff_percentile_lower  \
# 0    -1.66  0.41   ...       3562.0                3213.67
# 1    -2.23  0.19   ...          NaN                    NaN
# 2    -2.26  0.19   ...          NaN                    NaN
# 3    -2.27  0.18   ...          NaN                    NaN
#
#    teff_percentile_upper  radius_sigma  lum_sigma  teff_sigma  sinI_s  \
# 0                3929.82           NaN        NaN     358.077     NaN
# 1                    NaN           NaN        NaN         NaN     NaN
# 2                    NaN           NaN        NaN         NaN     NaN
# 3                    NaN           NaN        NaN         NaN     NaN
#
#    sinI_s_sigma   V  V_sigma
# 0           NaN NaN      NaN
# 1           NaN NaN      NaN
# 2           NaN NaN      NaN
# 3           NaN NaN      NaN
#
# [4 rows x 41 columns]

# %% [markdown]
# ## Initiate Database Connection

# %%
c = SkyCoord(ra = df.RA, dec = df.Dec, unit=(u.deg, u.deg))

# %% [markdown]
# ## Query fp_psc : 2MASS All-Sky Point Source Catalog (PSC)

# %%
from astroquery.irsa import Irsa

# %%
features = [
            "j_m", "j_msigcom", 
            "h_m", "h_msigcom",
            "k_m", "k_msigcom"
           ]
from astropy.coordinates import match_coordinates_sky

def retrieve(idx, df):
    global features
    global c
    temp = Irsa.query_region(c[idx], 
                     radius=5*u.arcsecond,
                    catalog="fp_psc").to_pandas()
    
    catalog = SkyCoord(ra=temp.ra, dec=temp.dec,
                       unit=(u.deg, u.deg))
    
    i,_,_ = match_coordinates_sky(c[idx], catalog)
    
    for feat in features:
        df.at[idx, feat] = temp.at[int(i), feat]

# %%
[retrieve(i, df) for i, row in df.iterrows()]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# 23   2.63    -1.20  0.58    ...      0.497830      0.090772  108.671556
# 24   2.85    -2.25  0.19    ...           NaN           NaN         NaN
# 25   2.84    -1.93  0.29    ...           NaN           NaN         NaN
# 26   2.80    -2.06  0.25    ...           NaN           NaN         NaN
# 27   2.79    -2.12  0.22    ...           NaN           NaN         NaN
# 28   2.74    -1.84  0.33    ...           NaN           NaN         NaN
# 29   2.20    -0.64  0.79    ...      1.874850           NaN    4.640371
# ..    ...      ...   ...    ...           ...           ...         ...
# 289  2.80    -2.33  0.17    ...           NaN           NaN         NaN
# 290  2.78    -1.91  0.30    ...           NaN           NaN         NaN
# 291  2.71    -1.62  0.42    ...           NaN           NaN         NaN
# 292  1.55    -0.14  1.01    ...      0.844656           NaN    9.944875
# 293  1.70    -0.34  0.92    ...      1.690407           NaN    5.087531
# 294  2.88    -2.21  0.20    ...           NaN           NaN         NaN
# 295  1.96    -0.54  0.83    ...      1.721543           NaN    4.937431
# 296  2.79    -1.75  0.37    ...           NaN           NaN         NaN
# 297  1.68    -0.35  0.91    ...      1.332052           NaN    6.230990
# 298  2.78    -2.00  0.27    ...           NaN           NaN         NaN
# 299  2.69    -1.55  0.45    ...      0.973865      0.153173   18.893784
# 300  2.74    -1.73  0.38    ...           NaN           NaN         NaN
# 301  2.43    -1.03  0.64    ...           NaN           NaN         NaN
# 302  2.67    -1.24  0.57    ...           NaN           NaN         NaN
# 303  2.81    -1.83  0.34    ...           NaN           NaN         NaN
# 304  2.75    -1.89  0.31    ...           NaN           NaN         NaN
# 305  1.60    -0.20  0.98    ...      1.474328           NaN    5.765337
# 306  2.06    -0.69  0.77    ...      0.773336           NaN   11.249968
# 307  2.77    -1.90  0.31    ...           NaN           NaN         NaN
# 308  2.27    -0.52  0.84    ...      0.465326      0.022927  103.798110
# 309  1.35     0.08  1.12    ...      0.813308      0.071768   25.451604
# 310  2.03    -0.27  0.95    ...      1.163191      0.314515    8.339128
# 311  1.81    -0.41  0.88    ...      1.253663           NaN    6.700364
# 312  2.30    -0.91  0.69    ...      1.417631           NaN    5.995921
# 313  2.58    -1.24  0.57    ...      1.586708           NaN    6.428403
# 314  2.00    -0.62  0.80    ...      2.160448           NaN    3.980655
# 315  2.49    -1.10  0.62    ...      2.525567           NaN    4.197078
# 316  2.37    -0.89  0.69    ...      1.104411           NaN    7.696414
# 317  2.34    -0.89  0.70    ...      0.550246      0.059946   47.615029
# 318  1.59    -0.13  1.01    ...      0.779923      0.152197   14.488617
#
#        V_sigma     j_m  j_msigcom     h_m  h_msigcom     k_m  k_msigcom
# 0          NaN  12.643      0.026  12.004      0.030  11.830      0.022
# 1          NaN  14.081      0.024  13.485      0.031  13.162      0.028
# 2          NaN  14.145      0.026  13.491      0.034  13.194      0.033
# 3          NaN  14.244      0.028  13.568      0.035  13.250      0.029
# 4          NaN  12.747      0.021  12.168      0.024  11.902      0.020
# 5          NaN  13.868      0.026  13.296      0.024  13.057      0.030
# 310   0.296565   9.677      0.026   9.230      0.027   9.054      0.018
# 311   0.604495   9.949      0.022   9.564      0.027   9.439      0.021
# 312   0.418977  11.044      0.019  10.493      0.016  10.372      0.018
# 313   0.795103  11.773      0.024  11.095      0.014  10.913      0.022
# 314   0.154740  10.616      0.021  10.077      0.029   9.957      0.021
# 315   0.522772  11.493      0.021  10.828      0.015  10.655      0.021
# 316   0.694357   9.949      0.022   9.564      0.027   9.439      0.021
# 317   4.295746   9.949      0.022   9.564      0.027   9.439      0.021
# 318   0.862596   9.535      0.021   9.219      0.015   9.137      0.022
#
# [319 rows x 47 columns]

# %%
df_trim = df[["RA", "Dec", 
              "parallax", "parallax_error",
              "j_m", "j_msigcom",
              "h_m", "h_msigcom",
              "k_m", "k_msigcom", "Name"
             ]]

# %%
df_trim["band"] = "kmag"
# Out:
# /Users/kaimibk/miniconda3/envs/UHenv/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_trim[["RA", "Dec", 
              "parallax", "parallax_error",
              "j_m", "j_msigcom",
              "h_m", "h_msigcom",
              "k_m", "k_msigcom", "band", "Name"
             ]].to_csv(main_dir+"MN_17_3616_gaia2.csv")

# %%
import sys
sys.path.append("/Users/kaimibk/Documents/Research/isoclassify/")
sys.path.append("/Users/kaimibk/Documents/Research/mwdust-master/")
from isoclassify import *
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-6b3dac532eb6> in <module>()
#       2 sys.path.append("/Users/kaimibk/Documents/Research/isoclassify/")
#       3 sys.path.append("/Users/kaimibk/Documents/Research/mwdust-master/")
# ----> 4 from isoclassify import *
#
# /Users/kaimibk/Documents/Research/isoclassify/isoclassify.py in <module>()
#      15 from astropy.coordinates import SkyCoord
#      16 from dustmaps.bayestar import BayestarWebQuery
# ---> 17 import mwdust
#      18
#      19 import grid.classify_grid
#
# /Users/kaimibk/Documents/Research/mwdust-master/mwdust/__init__.py in <module>()
# ----> 1 from mwdust.SFD import SFD
#       2 from mwdust.Marshall06 import Marshall06
#       3 from mwdust.Drimmel03 import Drimmel03
#       4 from mwdust.Sale14 import Sale14
#       5 from mwdust.Green15 import Green15
#
# /Users/kaimibk/Documents/Research/mwdust-master/mwdust/SFD.py in <module>()
#       5 ###############################################################################
#       6 import numpy
# ----> 7 from mwdust.util.read_SFD import read_SFD_EBV
#       8 from mwdust.util.extCurves import aebv
#       9 from mwdust.DustMap3D import DustMap3D
#
# /Users/kaimibk/Documents/Research/mwdust-master/mwdust/util/read_SFD.py in <module>()
#      25             break
#      26 if _lib is None:
# ---> 27     raise IOError('SFD/C module not found')
#      28
#      29 #MAP path names
#
# IOError: SFD/C module not found

# %%
kwargs={'method': 'direct', 
        'id_starname': "star name in the csv file", 
        'csv': main_dir+'MN_17_3616_gaia2.csv', 
        'outdir': out_dir, 'dust': 'allsky'}
run(**kwargs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7f2f7a1bbf13> in <module>()
#       3         'csv': main_dir+'MN_17_3616_gaia2.csv',
#       4         'outdir': out_dir, 'dust': 'allsky'}
# ----> 5 run(**kwargs)
#
# NameError: name 'run' is not defined
